# %%
import pandas as pd

# %%
df_train = pd.read_csv('camping_train.csv')
df_train.head()
# Out:
#   camping_id                    nama_camping  \
# 0      C0001                    Buper Ipukan
# 1      C0002         Buper Huludayeh Trijaya
# 2      C0003              Buper Balong Dalem
# 3      C0004      Bumi Perkemahan Palutungan
# 4      C0005  Bumi Perkemahan Bukit Lambosir
#
#                                            deskripsi  \
# 0  Buper Ipukan adalah salah satu tempat camping ...
# 1  Hamparan hutan pinus nan asri menjadi daya tar...
# 2  Buper Balong Dalem merupakan bumi perkemahan y...
# 3  Bumi Perkemahan Palutungan merupakan tempat ca...
# 4  Bumi Perkemahan Bukit Lambosir lokasinya berad...
#
#                                               lokasi            jalan  \
# 0  Jl. Palutungan, Kec. Cigugur, Kabupaten Kuning...   Jl. Palutungan
# 1  Jl. Trijaya, Kertajati, Kabupaten Kuningan, Ja...      Jl. Trijaya
# 2  Jl. Babakan Mulya, Babakanmulya, Kec. Jalaksan...      Jl. Babakan
# 3  Jl. Cisantana, Kec. Cigugur, Kabupaten Kuninga...    Jl. Cisantana
# 4  Jl. Setianegara, Cilimus, Randobawagirang, Man...  Jl. Setianegara
#
#      kecamatan      kota    provinsi       jam buka  harga jumlah_review  \
# 0      Cigugur  Kuningan  Jawa Barat         24 jam  20000         1,356
# 1  Mandirancan  Kuningan  Jawa Barat  07.00 - 17.00  20000            42
# 2    Jalaksana  Kuningan  Jawa Barat  08.00 - 18.00  20000           756
# 3      Cigugur  Kuningan  Jawa Barat         24 jam  15000           471
# 4  Mandirancan  Kuningan  Jawa Barat         24 jam  15000           122
#
#    rating  latitude   longitude
# 0     4.5 -6.938424  108.432812
# 1     4.7 -6.844443  108.462310
# 2     4.3 -6.919138  108.476678
# 3     4.4 -6.946187  108.433004
# 4     4.4 -6.862843  108.453455

# %%
df_test = pd.read_csv('camping_test.csv')
df_test.head()
# Out:
#   camping_id                                nama_camping  \
# 0      C0048  Baru Beureum (Camp & Track Mt. Manglayang)
# 1      C0049              Camping Ground Samalengoh Camp
# 2      C0050                Bumi Perkemahan Mandalawangi
# 3      C0051                       Gunung Gede Pangrango
# 4      C0052          Bumi Perkemahan Bukit Golf Cibodas
#
#                                            deskripsi  \
# 0  Camping di Baru Beureum cocok untuk kamu yang ...
# 1  Samalengoh Camp berada di Desa Guntur, tidak j...
# 2  Bumi perkemahan Mandalawangi memang berlokasi ...
# 3  Berwisata ke Cianjur pastilah kurang lengkap j...
# 4  Bumi Perkemahan Bukit Golf Cibodas merupakan c...
#
#                                               lokasi                   jalan  \
# 0  Jl. Ciloa, Kec. Sukasari, Kabupaten Sumedang, ...               Jl. Ciloa
# 1  Jl. Gunturmekar, Kec. Tanjungkerta, Kabupaten ...         Jl. Gunturmekar
# 2  Jl. Kebun Raya Cibodas, Cimacan, Kec. Cipanas,...  Jl. Kebun Raya Cibodas
# 3  Jl. Cipendawa, Kec. Pacet, Kabupaten Cianjur, ...           Jl. Cipendawa
# 4  Jl. Bukit Golf Cibodas, Sindangjaya, Kec. Cipa...  Jl. Bukit Golf Cibodas
#
#       kecamatan      kota    provinsi jam buka  harga jumlah_review  rating  \
# 0      Sukasari  Sumedang  Jawa Barat   24 jam   5000           181     4.6
# 1  Tanjungkerta  Sumedang  Jawa Barat   24 jam  10000           174     4.7
# 2       Cipanas   Cianjur  Jawa Barat   24 jam  30000         4,660     4.5
# 3         Pacet   Cianjur  Jawa Barat   24 jam  30000            56     4.7
# 4       Cipanas   Cianjur  Jawa Barat   24 jam  30000           752     4.6
#
#    latitude   longitude
# 0 -6.879858  107.757386
# 1 -6.810671  107.885703
# 2 -6.736805  107.003604
# 3 -6.726838  107.017459
# 4 -6.739980  107.001443

# %%
df_train2 = df_train[["rating", "latitude", "longitude"]]
df_train2.head()
# Out:
#    rating  latitude   longitude
# 0     4.5 -6.938424  108.432812
# 1     4.7 -6.844443  108.462310
# 2     4.3 -6.919138  108.476678
# 3     4.4 -6.946187  108.433004
# 4     4.4 -6.862843  108.453455

# %%
df_test2 = df_test[["harga", "latitude", "longitude"]]
df_test2.head()
# Out:
#    harga  latitude   longitude
# 0   5000 -6.879858  107.757386
# 1  10000 -6.810671  107.885703
# 2  30000 -6.736805  107.003604
# 3  30000 -6.726838  107.017459
# 4  30000 -6.739980  107.001443

# %%
train_df2_np = df_train2.to_numpy()
X_train, y_train = train_df2_np[:, :-1], train_df2_np[:, -1]
X_train.shape, y_train.shape
# Out:
# ((47, 2), (47,))

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

linear_model = LinearRegression().fit(X_train, y_train)
linear_train_preds = linear_model.predict(X_train)
mean_absolute_error(linear_train_preds, y_train)
# Out:
# 0.28366191882814373

# %%
test_df2_np = df_test2.to_numpy()
X_test, y_test = test_df2_np[:, :-1], test_df2_np[:, -1]
X_test.shape, y_test.shape
# Out:
# ((13, 2), (13,))

# %%
linear_test_preds = linear_model.predict(X_test)
mean_absolute_error(linear_test_preds, y_test)
# Out:
# 36.795577599041444

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(n_estimators=10, max_depth=5).fit(X_train, y_train)
rf_train_preds = rf.predict(X_train)
rf_test_preds = rf.predict(X_test)
mean_absolute_error(rf_train_preds, y_train), mean_absolute_error(rf_test_preds, y_test)
# Out:
# (0.0562331165171519, 0.6241893260303066)

# %%
from sklearn.model_selection import train_test_split
X_val, X_hold, y_val, y_hold = train_test_split(X_test, y_test, test_size=0.5)
X_val.shape, X_hold.shape, y_val.shape, y_hold.shape
# Out:
# ((6, 2), (7, 2), (6,), (7,))

# %%
linear_val_preds = linear_model.predict(X_val)
mean_absolute_error(y_train, linear_train_preds), mean_absolute_error(y_val, linear_val_preds)
# Out:
# (0.28366191882814373, 38.013965608099625)

# %%
rf_val_preds = rf.predict(X_val)
mean_absolute_error(y_train, rf_train_preds), mean_absolute_error(y_val, rf_val_preds)
# Out:
# (0.0562331165171519, 0.565440949116161)

# %%
rf_hold_preds = rf.predict(X_hold)
mean_absolute_error(y_hold, rf_hold_preds)
# Out:
# 0.6745450776710028
